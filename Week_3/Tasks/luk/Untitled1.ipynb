# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# /home/artem/miniconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.plot([14.5, 15., 17.33, 18.5, 19.5, 20.75, 25.], [37.2, 37.8, 38.4, 37.8, 37.2, 37.6, 38.4], color = 'red', label = '28.10')
plt.plot([9.833, 12.5, 13.33, 17.33, 18.67, 20.5, 21.5, 22., 22.5], [36.5, 37.3, 37.6, 37.9, 37.6, 37.9, 38.3, 38.1, 38.5], color = 'blue', label = '29.10')
plt.plot([10.667, 16., 18.42, 20., 20.67, 21.33, 22.], [37.2, 37.4, 38., 38.7, 37.9, 38.8, 38.5], color = 'black', label = '30.10')
plt.legend(loc=4)
plt.title("Dima's temperature")
plt.ylabel('Temperature')
plt.xlabel('Time')
plt.show()
